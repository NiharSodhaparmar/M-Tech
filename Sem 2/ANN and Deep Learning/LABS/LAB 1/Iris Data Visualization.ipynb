# %% [markdown]
# ### Data Visualization turns data into images that nearly anyone can understand making them invaluable for explaining the significance of digits to people who are more visually oriented

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
columns = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]

# %%
iris_data = pd.read_csv("./iris.data", names = columns)

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_data.shape
# Out:
# (150, 5)

# %% [markdown]
# ## 1.) Scatterplot:
# ### This is used to find a relationship in a bivariate data. It is most commonly used to find correlations between two continuous variables. Here, we’ll see scatter plot for Petal Length and Petal Width using matplotlib.

# %%
for i in columns:
    for j in columns:    
        if i == "name" or j == "name":
            continue
        else:
            plt.figure()
            plt.scatter(iris_data[i], iris_data[j], color="green")
            plt.title("Scatter Plot for bivariate analysis")
            plt.xlabel(i)
            plt.ylabel(j)
# Out:
# C:\Users\nihar\AppData\Local\Temp\ipykernel_11864\1216395372.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %% [markdown]
# ## 2.) Histogram:
# ### The histogram shows the distribution of a continuous variable.  It can discover the frequency distribution for a single variable in a univariate analysis.

# %%
for i in columns:
    if i != "species":
        plt.figure()
        plt.hist(iris_data[i], color="green", bins = 25)
        plt.title("Histogram for " + i)
        plt.xlabel(i)
        plt.ylabel("Frequency")

# %% [markdown]
# ## 3.) Bar Chart:
# ### Bar Chart or Bar Plot is used to represent categorical data with vertical or horizontal bars. It is a general plot that allows you to aggregate the categorical data based on some function, by default the mean.

# %%
for i in columns:
    if i != "species":
        plt.figure()
        sns.barplot(iris_data, x=iris_data["species"], y=iris_data[i])
        plt.title("Barplot")

# %% [markdown]
# ## 4.) Pie Chart:
# ### Pie Chart is a type of plot which is used to represent the proportion of each category in categorical data. The whole pie is divided into slices which are equal to the number of categories.

# %%
iris_data["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
labels = ["Setosa", "Versicolor", "Virginica"]
sizes = list(iris_data["species"].value_counts())
plt.pie(sizes, labels=labels, explode=(0.1,0.1,0.1))
plt.axis("equal")
plt.legend()

# %% [markdown]
# ## 5.) Countplot:
# ### Countplot is similar to a bar plot except that we only pass the X-axis and Y-axis represents explicitly counting the number of occurrences. Each bar represents count for each category of species.

# %%
sns.countplot(x="species", data=iris_data)
plt.title("Countplot for species")
# Out:
# Text(0.5, 1.0, 'Countplot for species')

# %% [markdown]
# ## 6.) Boxplot:
# ### Boxplot is used to show the distribution of a variable. The box plot is a standardized way of displaying the distribution of data based on the five-number summary: minimum, first quartile, median, third quartile, and maximum.

# %%
for i in columns:
    if i != "species":
        plt.figure()
        sns.boxplot(x=iris_data[i], data=iris_data)
        plt.title("Boxplot showing distribution for " + i)

# %% [markdown]
# ### Boxplot for entire dataset

# %%
sns.boxplot(data= iris_data, orient='h')
plt.title("Boxplot for entire dataset")
# Out:
# Text(0.5, 1.0, 'Boxplot for entire dataset')

# %% [markdown]
# ## 7.) Heatmap:
# ### Heatmap is a type of Matrix plot that allows you to plot data as color-encoded matrices. It is mostly used to find multi-collinearity in a dataset.

# %%
iris_data.corr()
# Out:
# C:\Users\nihar\AppData\Local\Temp\ipykernel_11864\514728938.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_data.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(iris_data.corr(), cmap='coolwarm', annot=True)
# Out:
# C:\Users\nihar\AppData\Local\Temp\ipykernel_11864\1064487477.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris_data.corr(), cmap='coolwarm', annot=True)
# <AxesSubplot: >

# %% [markdown]
# ## 8.) Distplot:
# ### The Distplot shows the distribution of a univariate data

# %%
for i in columns:
    if i != "species":
        sns.displot(iris_data[i], bins=25, kde=True)
