# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
citrus_data = pd.read_csv("./citrus.csv")

# %%
columns = ["name", "diameter", "weight", "red", "green", "blue"]

# %%
citrus_data.shape
# Out:
# (10000, 6)

# %%
citrus_data
# Out:
#             name  diameter  weight  red  green  blue
# 0         orange      2.96   86.76  172     85     2
# 1         orange      3.91   88.05  166     78     3
# 2         orange      4.42   95.17  156     81     2
# 3         orange      4.47   95.60  163     81     4
# 4         orange      4.48   95.76  161     72     9
# ...          ...       ...     ...  ...    ...   ...
# 9995  grapefruit     15.35  253.89  149     77    20
# 9996  grapefruit     15.41  254.67  148     68     7
# 9997  grapefruit     15.59  256.50  168     82    20
# 9998  grapefruit     15.92  260.14  142     72    11
# 9999  grapefruit     16.45  261.51  152     74     2
#
# [10000 rows x 6 columns]

# %% [markdown]
# ## Pie chart

# %%
labels = ["Orange", "Grapefruit"]
sizes = list(citrus_data["name"].value_counts())
plt.pie(sizes, labels=labels)
plt.axis("equal")
plt.legend()

# %% [markdown]
# ## Barchart

# %%
for i in columns:
    if i!= "name":
        plt.figure()
        sns.barplot(citrus_data, x=citrus_data["name"], y=citrus_data[i])
        plt.title("Barplot")

# %% [markdown]
# ## Countplot

# %%
sns.countplot(x="name", data=citrus_data)
plt.title("Countplot for name")
# Out:
# Text(0.5, 1.0, 'Countplot for name')

# %% [markdown]
# ## Scatterplot

# %%
for i in columns:
    for j in columns:    
        if i == "name" or j == "name":
            continue
        else:
            plt.scatter(citrus_data[i], citrus_data[j], color="green")
            plt.title("Scatter Plot for bivariate analysis")
            plt.xlabel(i)
            plt.ylabel(j)
            plt.show()

# %% [markdown]
# ## Histogram

# %%
for i in columns:
    if i!= "name":        
        plt.figure()
        plt.hist(citrus_data[i], color="green", bins = 25)
        plt.title("Histogram")
        plt.xlabel(i)
        plt.ylabel("Frequency")

# %% [markdown]
# ## Boxplot

# %%
for i in columns:
    if i != "name":
        plt.figure()
        sns.boxplot(x=citrus_data[i], data=citrus_data)
        plt.title("Boxplot showing distribution for " + i)

# %% [markdown]
# ## Heatmap

# %%
sns.heatmap(citrus_data.corr(), cmap='coolwarm', annot=True)
# Out:
# C:\Users\nihar\AppData\Local\Temp\ipykernel_12200\2211263631.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(citrus_data.corr(), cmap='coolwarm', annot=True)
# <AxesSubplot: >

# %% [markdown]
# ## Displot

# %%
for i in columns:
    if i != "name":
        sns.displot(citrus_data[i], bins=25, kde=True)

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(citrus_data, hue="name")
