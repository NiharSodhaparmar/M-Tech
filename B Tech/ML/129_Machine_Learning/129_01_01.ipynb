# %% [markdown]
# # Exercise 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read data from Data_for_Transformation.csv
data=pd.read_csv('/home/nihar/Downloads/Data_for_Transformation.csv')

# %% [markdown]
# #### 1) Draw Scatter Plot between age and salary

# %%
plt.scatter(data['Age'],data['Salary']) 
plt.show()

# %% [markdown]
# #### 2) Draw Histogram of Salary

# %%
plt.hist(data['Salary'],bins=5)
plt.show()

# %% [markdown]
# #### 3) Plot pie chart of Country

# %%
country = data['Country']
d=dict()

for i in country:
    if i not in d:
        d.update({i:1})
    else:
        d[i]+=1
        
country_count=[]
country_name=[]

for i in d:
    country_count.append(d[i])
    country_name.append(i)

    
plt.pie(country_count,labels=country_name,autopct='%.3f%%')
plt.show()
